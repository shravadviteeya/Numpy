# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Drop rows with NaN value

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

df.dropna()
# By default axis = 0 for rows
# axis = 1 for rows
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# we have already dropped the NaN value
# But if i call the df again we will get the completed data
# So the dropna() is not dropping it permanently

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# we have already dropped the NaN value
# But if i call the df again we will get the completed data
# So the dropna() is not dropping it permanently
# So inorder to get the permanent delete use the function inplace = True by default it is False
df.dropna(inplace = True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df= pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.dropna(axis=1) # dropping the columns with NaN value initially columns were 12 now we have 9 columns but not permanent
# in case need permanent solution use inplace = True
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
# Find the count of NAN records

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Drop the columns where NaN value is more than 10

# %%
df.dropna(thresh=10)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis =1 , thresh =800) # IT WILL REMOVE THE COLUMNS IF THE NAN VALUE IS LESS THAN 800
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.dropna(axis =1 , how= "all")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
############################################### fill.na#######################################

# %%
df.fillna(value= "adviteeya")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male       22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female       38.0
# 2                               Heikkinen, Miss. Laina  female       26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       35.0
# 4                             Allen, Mr. William Henry    male       35.0
# ..                                                 ...     ...        ...
# ...

# %%
# In the age  where ever there is a NAN it will replace with mean of aga

# %%
df.fillna(value= df['Age'].mean)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# ...

# %%
################### KNN IMPUTATION #######################################
# E.G. CABIN

# %%
df.groupby('Survived').describe() # with respective every unique value in Survived
# Out:
#          PassengerId                                                     \
#                count        mean         std  min     25%    50%    75%
# Survived
# 0              549.0  447.016393  260.640469  1.0  211.00  455.0  675.0
# 1              342.0  444.368421  252.358840  2.0  250.75  439.5  651.5
#
#                 Pclass            ... Parch        Fare                        \
#             max  count      mean  ...   75%  max  count       mean        std
# Survived                          ...
# 0         891.0  549.0  2.531876  ...   0.0  6.0  549.0  22.117887  31.388207
# 1         890.0  342.0  1.950292  ...   1.0  5.0  342.0  48.395408  66.596998
#
#
#           min      25%   50%   75%       max
# Survived
# 0         0.0   7.8542  10.5  26.0  263.0000
# 1         0.0  12.4750  26.0  57.0  512.3292
#
# [2 rows x 48 columns]

# %%
df.groupby('Survived').describe()['PassengerId']
# Out:
#           count        mean         std  min     25%    50%    75%    max
# Survived
# 0         549.0  447.016393  260.640469  1.0  211.00  455.0  675.0  891.0
# 1         342.0  444.368421  252.358840  2.0  250.75  439.5  651.5  890.0

# %%
# Rotate the row into columns and column to row

# %%
df.groupby('Survived').describe()['PassengerId'].T
# Out:
# Survived           0           1
# count     549.000000  342.000000
# mean      447.016393  444.368421
# std       260.640469  252.358840
# min         1.000000    2.000000
# 25%       211.000000  250.750000
# 50%       455.000000  439.500000
# 75%       675.000000  651.500000
# max       891.000000  890.000000

# %%
df.groupby('Survived').describe()['PassengerId'].transpose()
# Out:
# Survived           0           1
# count     549.000000  342.000000
# mean      447.016393  444.368421
# std       260.640469  252.358840
# min         1.000000    2.000000
# 25%       211.000000  250.750000
# 50%       455.000000  439.500000
# 75%       675.000000  651.500000
# max       891.000000  890.000000

# %%
df1 = pd.read_csv("bank.csv" , delimiter=';')

# %%
df1
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df1['education'].unique()
# Out:
# array(['primary', 'secondary', 'tertiary', 'unknown'], dtype=object)

# %%
l=[]
for i in df1['education'].unique():
    l.append(df1[df1['education']== i])

# %%
df4= l[0]

# %%
df4
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
df5= l[1]

# %%
df5
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
df6= l[2]

# %%
df6
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
# ...

# %%
df7=l[3]

# %%
df7
# Out:
#       age          job   marital education default  balance housing loan  \
# 20     38   management  divorced   unknown      no        0     yes   no
# 27     67      retired   married   unknown      no      696      no   no
# 49     61       admin.   married   unknown      no     4629     yes   no
# 132    43  blue-collar   married   unknown     yes     -715     yes   no
# 133    48       admin.   married   unknown      no        0     yes   no
# ...   ...          ...       ...       ...     ...      ...     ...  ...
# 4337   73      retired   married   unknown      no      519      no   no
# 4342   50  blue-collar   married   unknown      no     2284     yes   no
# 4428   48  blue-collar   married   unknown      no      439     yes   no
# 4471   59   management   married   unknown      no     3534      no   no
# 4508   42       admin.   married   unknown      no      642     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %% [markdown]
# # CONCATENATION

# %%
############################################# MERGE and JOIN OPERATIONS ##############################################

# %%
# If we want to concatenate the data

# %%
"adviteeya " + "shrav"
# Out:
# 'adviteeya shrav'

# %%
pd.concat([df5,df6]) # rowwise concatenation operation
# Out:
#       age            job   marital  education default  balance housing loan  \
# 1      33       services   married  secondary      no     4789     yes  yes
# 4      59    blue-collar   married  secondary      no        0     yes   no
# 7      39     technician   married  secondary      no      147     yes   no
# 10     39       services   married  secondary      no     9374     yes   no
# 11     43         admin.   married  secondary      no      264     yes   no
# ...   ...            ...       ...        ...     ...      ...     ...  ...
# 4501   34     management   married   tertiary      no      297     yes   no
# 4506   42     unemployed  divorced   tertiary      no     -166      no   no
# 4509   51     technician   married   tertiary      no     2506      no   no
# 4517   57  self-employed   married   tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single   tertiary      no     1136     yes  yes
#
# ...

# %%
# optimizing df5 and df6 to 5 fields

# %%
df5 =df5.head()

# %%
df5
# Out:
#     age          job  marital  education default  balance housing loan  \
# 1    33     services  married  secondary      no     4789     yes  yes
# 4    59  blue-collar  married  secondary      no        0     yes   no
# 7    39   technician  married  secondary      no      147     yes   no
# 10   39     services  married  secondary      no     9374     yes   no
# 11   43       admin.  married  secondary      no      264     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 1   cellular   11   may       220         1    339         4  failure  no
# 4    unknown    5   may       226         1     -1         0  unknown  no
# 7   cellular    6   may       151         2     -1         0  unknown  no
# 10   unknown   20   may       273         1     -1         0  unknown  no
# 11  cellular   17   apr       113         2     -1         0  unknown  no

# %%
df6 =df6.head()
df6
# Out:
#    age            job  marital education default  balance housing loan  \
# 2   35     management   single  tertiary      no     1350     yes   no
# 3   30     management  married  tertiary      no     1476     yes  yes
# 5   35     management   single  tertiary      no      747      no   no
# 6   36  self-employed  married  tertiary      no      307     yes   no
# 8   41   entrepreneur  married  tertiary      no      221     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 5  cellular   23   feb       141         2    176         3  failure  no
# 6  cellular   14   may       341         1    330         2    other  no
# 8   unknown   14   may        57         2     -1         0  unknown  no

# %%
pd.concat([df5,df6]) # ROWWISE CONCATENATION
# Out:
#     age            job  marital  education default  balance housing loan  \
# 1    33       services  married  secondary      no     4789     yes  yes
# 4    59    blue-collar  married  secondary      no        0     yes   no
# 7    39     technician  married  secondary      no      147     yes   no
# 10   39       services  married  secondary      no     9374     yes   no
# 11   43         admin.  married  secondary      no      264     yes   no
# 2    35     management   single   tertiary      no     1350     yes   no
# 3    30     management  married   tertiary      no     1476     yes  yes
# 5    35     management   single   tertiary      no      747      no   no
# 6    36  self-employed  married   tertiary      no      307     yes   no
# 8    41   entrepreneur  married   tertiary      no      221     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 1   cellular   11   may       220         1    339         4  failure  no
# ...

# %%
# optimizing df5 and df6 to 5 columns

# %%
df1.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df5 = df5.head()[['age', 'job', 'marital']]

# %%
df5
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
df6 = df6.head()[['age', 'job', 'marital']]

# %%
df6
# Out:
#    age            job  marital
# 2   35     management   single
# 3   30     management  married
# 5   35     management   single
# 6   36  self-employed  married
# 8   41   entrepreneur  married

# %%
pd.concat([df5,df6], axis=1) # currently there are two columns with the same name
# Out:
#      age          job  marital   age            job  marital
# 1   33.0     services  married   NaN            NaN      NaN
# 2    NaN          NaN      NaN  35.0     management   single
# 3    NaN          NaN      NaN  30.0     management  married
# 4   59.0  blue-collar  married   NaN            NaN      NaN
# 5    NaN          NaN      NaN  35.0     management   single
# 6    NaN          NaN      NaN  36.0  self-employed  married
# 7   39.0   technician  married   NaN            NaN      NaN
# 8    NaN          NaN      NaN  41.0   entrepreneur  married
# 10  39.0     services  married   NaN            NaN      NaN
# 11  43.0       admin.  married   NaN            NaN      NaN

# %%
df8 = pd.concat([df5,df6], axis=1)
df8
# Out:
#      age          job  marital   age            job  marital
# 1   33.0     services  married   NaN            NaN      NaN
# 2    NaN          NaN      NaN  35.0     management   single
# 3    NaN          NaN      NaN  30.0     management  married
# 4   59.0  blue-collar  married   NaN            NaN      NaN
# 5    NaN          NaN      NaN  35.0     management   single
# 6    NaN          NaN      NaN  36.0  self-employed  married
# 7   39.0   technician  married   NaN            NaN      NaN
# 8    NaN          NaN      NaN  41.0   entrepreneur  married
# 10  39.0     services  married   NaN            NaN      NaN
# 11  43.0       admin.  married   NaN            NaN      NaN

# %%
# How will you select age from d8 ?

# use of iloc # it will take inbuilt index location starting from 0,1.. for both rows and columns

# %% [markdown]
# # iloc

# %%
df8['age']
# Out:
#      age   age
# 1   33.0   NaN
# 2    NaN  35.0
# 3    NaN  30.0
# 4   59.0   NaN
# 5    NaN  35.0
# 6    NaN  36.0
# 7   39.0   NaN
# 8    NaN  41.0
# 10  39.0   NaN
# 11  43.0   NaN

# %%
df8
# Out:
#      age          job  marital   age            job  marital
# 1   33.0     services  married   NaN            NaN      NaN
# 2    NaN          NaN      NaN  35.0     management   single
# 3    NaN          NaN      NaN  30.0     management  married
# 4   59.0  blue-collar  married   NaN            NaN      NaN
# 5    NaN          NaN      NaN  35.0     management   single
# 6    NaN          NaN      NaN  36.0  self-employed  married
# 7   39.0   technician  married   NaN            NaN      NaN
# 8    NaN          NaN      NaN  41.0   entrepreneur  married
# 10  39.0     services  married   NaN            NaN      NaN
# 11  43.0       admin.  married   NaN            NaN      NaN

# %%
len(df8)
# Out:
# 10

# %%
df8.iloc[[1,2,3,4,5,6,7,8,9],[1,4]]
# Out:
#             job            job
# 2           NaN     management
# 3           NaN     management
# 4   blue-collar            NaN
# 5           NaN     management
# 6           NaN  self-employed
# 7    technician            NaN
# 8           NaN   entrepreneur
# 10     services            NaN
# 11       admin.            NaN

# %% [markdown]
# # loc

# %%
df8.loc[[8,10]]
# Out:
#      age       job  marital   age           job  marital
# 8    NaN       NaN      NaN  41.0  entrepreneur  married
# 10  39.0  services  married   NaN           NaN      NaN

# %%
df5
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
df5.loc[[4,11], ['job', 'marital']]
# Out:
#             job  marital
# 4   blue-collar  married
# 11       admin.  married

# %%
df5.loc[[4,7], ['age','marital']]
# Out:
#    age  marital
# 4   59  married
# 7   39  married

# %%
df5
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
df6
# Out:
#    age            job  marital
# 2   35     management   single
# 3   30     management  married
# 5   35     management   single
# 6   36  self-employed  married
# 8   41   entrepreneur  married

# %% [markdown]
# # MERGE OPERATIONS#

# %%
pd.merge(df5,df6)
# Out:
# Empty DataFrame
# Columns: [age, job, marital]
# Index: []

# %%
# use of on parameter

# %%
pd.merge(df5,df6, on ='marital')
# Out:
#     age_x        job_x  marital  age_y          job_y
# 0      33     services  married     30     management
# 1      33     services  married     36  self-employed
# 2      33     services  married     41   entrepreneur
# 3      59  blue-collar  married     30     management
# 4      59  blue-collar  married     36  self-employed
# 5      59  blue-collar  married     41   entrepreneur
# 6      39   technician  married     30     management
# 7      39   technician  married     36  self-employed
# 8      39   technician  married     41   entrepreneur
# 9      39     services  married     30     management
# 10     39     services  married     36  self-employed
# 11     39     services  married     41   entrepreneur
# 12     43       admin.  married     30     management
# 13     43       admin.  married     36  self-employed
# 14     43       admin.  married     41   entrepreneur

# %%
pd.merge(df5,df6,left_on= 'marital',right_on= 'marital')
# Out:
#     age_x        job_x  marital  age_y          job_y
# 0      33     services  married     30     management
# 1      33     services  married     36  self-employed
# 2      33     services  married     41   entrepreneur
# 3      59  blue-collar  married     30     management
# 4      59  blue-collar  married     36  self-employed
# 5      59  blue-collar  married     41   entrepreneur
# 6      39   technician  married     30     management
# 7      39   technician  married     36  self-employed
# 8      39   technician  married     41   entrepreneur
# 9      39     services  married     30     management
# 10     39     services  married     36  self-employed
# 11     39     services  married     41   entrepreneur
# 12     43       admin.  married     30     management
# 13     43       admin.  married     36  self-employed
# 14     43       admin.  married     41   entrepreneur

# %%
# use of how
# it will consider everything from left side and common from the right side

# %%
pd.merge(df5,df6,on = 'marital', how = 'left')
# Out:
#     age_x        job_x  marital  age_y          job_y
# 0      33     services  married     30     management
# 1      33     services  married     36  self-employed
# 2      33     services  married     41   entrepreneur
# 3      59  blue-collar  married     30     management
# 4      59  blue-collar  married     36  self-employed
# 5      59  blue-collar  married     41   entrepreneur
# 6      39   technician  married     30     management
# 7      39   technician  married     36  self-employed
# 8      39   technician  married     41   entrepreneur
# 9      39     services  married     30     management
# 10     39     services  married     36  self-employed
# 11     39     services  married     41   entrepreneur
# 12     43       admin.  married     30     management
# 13     43       admin.  married     36  self-employed
# 14     43       admin.  married     41   entrepreneur

# %%
# it will consider everything from right  side and common from the left side

# %%
pd.merge(df5,df6, on = 'marital', how = 'right')
# Out:
#     age_x        job_x  marital  age_y          job_y
# 0     NaN          NaN   single     35     management
# 1    33.0     services  married     30     management
# 2    59.0  blue-collar  married     30     management
# 3    39.0   technician  married     30     management
# 4    39.0     services  married     30     management
# 5    43.0       admin.  married     30     management
# 6     NaN          NaN   single     35     management
# 7    33.0     services  married     36  self-employed
# 8    59.0  blue-collar  married     36  self-employed
# 9    39.0   technician  married     36  self-employed
# 10   39.0     services  married     36  self-employed
# 11   43.0       admin.  married     36  self-employed
# 12   33.0     services  married     41   entrepreneur
# 13   59.0  blue-collar  married     41   entrepreneur
# 14   39.0   technician  married     41   entrepreneur
# 15   39.0     services  married     41   entrepreneur
# ...

# %%
pd.merge(df5,df6, on = 'marital', how = 'outer')
# Out:
#     age_x        job_x  marital  age_y          job_y
# 0    33.0     services  married     30     management
# 1    33.0     services  married     36  self-employed
# 2    33.0     services  married     41   entrepreneur
# 3    59.0  blue-collar  married     30     management
# 4    59.0  blue-collar  married     36  self-employed
# 5    59.0  blue-collar  married     41   entrepreneur
# 6    39.0   technician  married     30     management
# 7    39.0   technician  married     36  self-employed
# 8    39.0   technician  married     41   entrepreneur
# 9    39.0     services  married     30     management
# 10   39.0     services  married     36  self-employed
# 11   39.0     services  married     41   entrepreneur
# 12   43.0       admin.  married     30     management
# 13   43.0       admin.  married     36  self-employed
# 14   43.0       admin.  married     41   entrepreneur
# 15    NaN          NaN   single     35     management
# ...

# %% [markdown]
# # JOIN OPERATIONS #####################################

# %%
df5
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
df5.set_index('age')
# Out:
#              job  marital
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
df5_age = df5.set_index('age')

# %%
df5_age
# Out:
#              job  marital
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
df6
# Out:
#    age            job  marital
# 2   35     management   single
# 3   30     management  married
# 5   35     management   single
# 6   36  self-employed  married
# 8   41   entrepreneur  married

# %% [markdown]
# # how to select any column as index column #####################

# %%
df6_age = df6.set_index('age')
df6_age
# Out:
#                job  marital
# age
# 35      management   single
# 30      management  married
# 35      management   single
# 36   self-employed  married
# 41    entrepreneur  married

# %%
df5_age.join(df6_age)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-139-ace1c25e972e> in <module>
# ----> 1 df5_age.join(df6_age)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    8108         5  K5  A5  NaN
#    8109         """
# -> 8110         return self._join_compat(
#    8111             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    8112         )
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    8133                     sort=sort,
#    8134                 )
# -> 8135             return merge(
#    8136                 self,
#    8137                 other,
#
# ...

# %%
df5_age
# Out:
#              job  marital
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
df5_age.rename(columns= {"job": "job1", "marital":"marital1"}, inplace= True)

# %%
df5_age
# Out:
#             job1 marital1
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
df5_age.join(df6_age)
# Out:
#             job1 marital1  job marital
# age
# 33      services  married  NaN     NaN
# 39    technician  married  NaN     NaN
# 39      services  married  NaN     NaN
# 43        admin.  married  NaN     NaN
# 59   blue-collar  married  NaN     NaN

# %%
df5_age.join(df6_age, how="inner")
# Out:
# Empty DataFrame
# Columns: [job1, marital1, job, marital]
# Index: []

# %%
df5_age.join(df6_age, how="left")
# Out:
#             job1 marital1  job marital
# age
# 33      services  married  NaN     NaN
# 39    technician  married  NaN     NaN
# 39      services  married  NaN     NaN
# 43        admin.  married  NaN     NaN
# 59   blue-collar  married  NaN     NaN

# %%
df5_age.join(df6_age, how="right")
# Out:
#     job1 marital1            job  marital
# age
# 30   NaN      NaN     management  married
# 35   NaN      NaN     management   single
# 35   NaN      NaN     management   single
# 36   NaN      NaN  self-employed  married
# 41   NaN      NaN   entrepreneur  married

# %%
# in case of join operation we have the flexibility of choosing index as join option

# %%
df5_age = df5_age.reset_index()

# %%
df5_age
# Out:
#    age         job1 marital1
# 0   33     services  married
# 1   59  blue-collar  married
# 2   39   technician  married
# 3   39     services  married
# 4   43       admin.  married
